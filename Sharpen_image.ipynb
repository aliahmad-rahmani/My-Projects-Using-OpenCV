# %% [markdown]
# <a href="https://colab.research.google.com/github/aliahmad-rahmani/My-Projects-Using-OpenCV/blob/main/Sharpen_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load the required packages
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# load the image into system memory
image = cv2.imread('/content/drive/MyDrive/LR_3.jpg', flags=cv2.IMREAD_COLOR)

# %%
# display the image to the screen
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
kernel = np.array([[0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]])
image_sharp = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)
cv2_imshow(image_sharp)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
